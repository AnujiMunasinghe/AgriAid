# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# Load the dataset from CSV
data = pd.read_csv('Historical.csv')

# %%
# Preprocess the data
crop_encoder = LabelEncoder()
region_encoder = LabelEncoder()
quarter_encoder = LabelEncoder()

crop = data['Crop']
region = data['Region']
demand = data['Demand (Kg)']
supply = data['Supply  (Kg)']
price = data['Price (Rs)']
quarter = data['Quarter']

crop_encoded = crop_encoder.fit_transform(crop)
region_encoded = region_encoder.fit_transform(region)
quarter_encoded = quarter_encoder.fit_transform(quarter)

# %%
# Concatenate the categorical features
X = pd.concat([pd.Series(crop_encoded), pd.Series(
    region_encoded), pd.Series(quarter_encoded)], axis=1)

scaler = MinMaxScaler()
demand_scaled = scaler.fit_transform(demand.values.reshape(-1, 1))
supply_scaled = scaler.fit_transform(supply.values.reshape(-1, 1))
price_scaled = scaler.fit_transform(price.values.reshape(-1, 1))

# %%
# Split the data into training and testing sets
X_train, X_test, y_demand_train, y_demand_test, y_supply_train, y_supply_test, y_price_train, y_price_test = train_test_split(
    X, demand_scaled, supply_scaled, price_scaled, test_size=0.2, random_state=42)

# %%
# Build the model
model = Sequential()
model.add(Dense(256, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3))

# %%
# Compile the model
model.compile(optimizer=Adam(), loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, [y_demand_train, y_supply_train,
          y_price_train], epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 6ms/step - loss: 2.9663
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4929
# Epoch 3/100
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2373
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5104
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2276
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1732
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6235
# Epoch 8/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5071
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4503
# Epoch 10/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3122
# Epoch 11/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2907
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2447
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2163
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1582
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1703
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1624
# Epoch 17/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1796
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1231
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1340
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1045
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1035
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0738
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0891
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0822
# Epoch 25/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0816
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0686
# Epoch 27/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0809
# Epoch 28/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0780
# Epoch 29/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0695
# Epoch 30/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0716
# Epoch 31/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0662
# Epoch 32/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0593
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0649
# Epoch 34/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0606
# Epoch 35/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0656
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0611
# Epoch 37/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0515
# Epoch 38/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0541
# Epoch 39/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0448
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0546
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0485
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0464
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0389
# Epoch 44/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0455
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0417
# Epoch 46/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0374
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0445
# Epoch 48/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0439
# Epoch 49/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0496
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0353
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 52/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0427
# Epoch 53/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0344
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0408
# Epoch 55/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0345
# Epoch 56/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0334
# Epoch 57/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0327
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0341
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0341
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0344
# Epoch 61/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0353
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0348
# Epoch 63/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0316
# Epoch 64/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0352
# Epoch 65/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0306
# Epoch 66/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0339
# Epoch 67/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0295
# Epoch 68/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0372
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0289
# Epoch 70/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0290
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0324
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0316
# Epoch 73/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 74/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0259
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0338
# Epoch 76/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0350
# Epoch 77/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0288
# Epoch 78/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0253
# Epoch 79/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0298
# Epoch 80/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 81/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0282
# Epoch 82/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0274
# Epoch 83/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0287
# Epoch 84/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0297
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0270
# Epoch 86/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0320
# Epoch 87/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0278
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0271
# Epoch 89/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0248
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0246
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0241
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0273
# Epoch 93/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0244
# Epoch 94/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0252
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0243
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0248
# Epoch 97/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0245
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0287
# Epoch 99/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0273
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0259

# %%
# Evaluate the model
loss = model.evaluate(X_test, [y_demand_test, y_supply_test, y_price_test])

print("Final Loss:", loss)
# Out:
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0036
# Final Loss: 0.0036317019257694483

# %%
# Save the trained model
model.save('trained_model.h5')

print("Trained model saved.")
# Out:
# Trained model saved.
